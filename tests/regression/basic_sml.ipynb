# %% [markdown]
# # SML/NJ Regression Tests
#
# Basic SML expressions that verify the kernel can evaluate code and produce output.

# %%
1 + 1;

# %%
"hello";

# %%
fun double x = x * 2;
double 5;

# %%
[1, 2, 3];

# %%
fun fib 0 = 0
  | fib 1 = 1
  | fib n = fib (n-1) + fib (n-2);
fib 10;
